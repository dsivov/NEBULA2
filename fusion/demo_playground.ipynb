# %%
import playground as pg

# %%
vg = pg.VisualGenome()
# Out:
# downloading data file image_data.json
#
# downloading data file scene_graphs.json
#
# downloading data file synsets.json
#
#
# parsing scene graphs. This may take a few minutes

# %%
img, sg = vg[1]

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=800x600 at 0x7FEFB8A3DE80>

# %%
rel = sg.relationships[0]

# %%
print(f'relationship {rel}')
for att in vars(rel):
    print(f'{att}: {getattr(rel, att)}')
# Out:
# relationship 15947: man wears backpack
# id: 15947
# subject: man
# predicate: wears
# object: backpack
# synset: [wear.v.01 - be dressed in]

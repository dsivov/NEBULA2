# %%
from action_detector import ActionDetector
import torch
# %load_ext autoreload
# %autoreload 2


# check GPU usage
print("Num GPUs Available: ", torch.cuda.device_count())

# create predictior with pretrained weights on AVA dataset (default arguments)
# weights currently (23.09.2021) in google drive:
#   https://drive.google.com/file/d/1hIzrTzR50pYwLLzu_5GpmEGY4Q-e1-BX/view
predictor = ActionDetector()
# Out:
# Num GPUs Available:  1
# loading model
# Loading pretrained model from /home/guy/NEBULA2/experts/actions/action_detector/STEP/pretrained/ava_step.pth
# Building I3D model...
# Building I3D head for global branch...
# Building I3D head for global branch...
# Building I3D head for global branch...
# Building I3D head for context branch...

# %%
import os

input_path = '/movies/scenecliptest00581.avi'
output_path = os.path.splitext(os.path.basename(input_path))[0] + '__OUT'

# %%
preds = predictor.predict_video(
    path_to_video='Movies/92357362',  # path to the foler containing the video frames
    im_format='frame%04d.jpg',        # image format in folder. use default if movie file
    source_fps=25,                    # use the correct movie FPS for best performance
    show_pbar=True,                   # show/hide progress bar
    num_workers=4                     # num dataloader threads
)

# the returned value is a list of predictoins, one for each processed frame.
# a prediction is a dictionary in format:
# {
#   'detection_boxes': a list of lists of floating points. each list is a box for a single
#                      object in format xyxy, with values between 0 and 1.
#   'detection_scores': a list of lists floating points. each list contains the confidence
#                       for every predicted action class in the matching box region.
#   'detection_classes': a list of lists of string action names, e.g. ["stand", "carry"], ["sing", "dance"], ["sit"], ...
# }
preds
# Out:
# Datalist len:  90
# 100%|██████████| 12/12 [01:08<00:00,  5.70s/it]
# [{'detection_boxes': [[0.10089424252510071,
#     0.17611941695213318,
#     0.8650935292243958,
#     0.8353102207183838]],
#   'detection_classes': [['stand']],
#   'detection_scores': [[0.6572124361991882]]},
#  {'detection_boxes': [[0.09323395043611526,
#     0.17460456490516663,
#     0.873678982257843,
#     0.8372406959533691]],
#   'detection_classes': [['stand']],
#   'detection_scores': [[0.5361649990081787]]},
#  {'detection_boxes': [[0.06828727573156357,
#     0.17347747087478638,
#     0.8943866491317749,
#     0.8303683400154114]],
#   'detection_classes': [['stand']],
#   'detection_scores': [[0.6247953772544861]]},
#  {'detection_boxes': [[0.07584136724472046,
#     0.18592552840709686,
#     0.8379368782043457,
#     0.8337756395339966]],
#   'detection_classes': [['stand']],
#   'detection_scores': [[0.5779935121536255]]},
#  {'detection_boxes': [[0.064101941883564,
#     0.18387676775455475,
#     0.8300074934959412,
#     0.8356735110282898]],
#   'detection_classes': [['stand']],
#   'detection_scores': [[0.6986482739448547]]},
#  {'detection_boxes': [[0.08537929505109787,
#     0.18387474119663239,
#     0.854612410068512,
#     0.8227397799491882]],
#   'detection_classes': [['stand']],
#   'detection_scores': [[0.6001566648483276]]},
#  {'detection_boxes': [[0.066110759973526,
#     0.16598038375377655,
#     0.8688661456108093,
#     0.8331879377365112]],
#   'detection_classes': [['stand']],
#   'detection_scores': [[0.7700873613357544]]},
#  {'detection_boxes': [], 'detection_classes': [], 'detection_scores': []},
#  {'detection_boxes': [[0.08062400668859482,
#     0.192977175116539,
#     0.8781071305274963,
#     0.8220688104629517]],
#   'detection_classes': [['stand']],
#   'detection_scores': [[0.69277024269104]]},
#  {'detection_boxes': [], 'detection_classes': [], 'detection_scores': []},
#  {'detection_boxes': [], 'detection_classes': [], 'detection_scores': []},
#  {'detection_boxes': [[0.17250657081604004,
#     0.4782814681529999,
#     0.2928546071052551,
#     0.6063442230224609]],
#   'detection_classes': [['sit', 'stand']],
#   'detection_scores': [[0.5050666332244873, 0.4480852782726288]]},
#  {'detection_boxes': [[0.17703217267990112,
#     0.4818786680698395,
#     0.291653037071228,
#     0.6055857539176941]],
#   'detection_classes': [['stand', 'sit']],
#   'detection_scores': [[0.4581161439418793, 0.40263631939888]]},
#  {'detection_boxes': [[0.17538338899612427,
#     0.48133862018585205,
#     0.2956528663635254,
#     0.6041898131370544]],
#   'detection_classes': [['sit', 'stand']],
#   'detection_scores': [[0.4722009301185608, 0.4246807396411896]]},
#  {'detection_boxes': [[0.17569944262504578,
#     0.4878040552139282,
#     0.2987228333950043,
#     0.6048852801322937]],
#   'detection_classes': [['sit']],
#   'detection_scores': [[0.6164612770080566]]},
#  {'detection_boxes': [[0.17763164639472961,
#     0.48705950379371643,
#     0.3010791838169098,
#     0.6042855381965637]],
#   'detection_classes': [['sit']],
#   'detection_scores': [[0.6086186766624451]]},
#  {'detection_boxes': [[0.17784465849399567,
#     0.4849054217338562,
#     0.29768073558807373,
#     0.6068671941757202]],
#   'detection_classes': [['sit']],
#   'detection_scores': [[0.5454115271568298]]},
#  {'detection_boxes': [[0.176796555519104,
#     0.4874843657016754,
#     0.29634082317352295,
#     0.6051331162452698]],
#   'detection_classes': [['sit']],
#   'detection_scores': [[0.5878917574882507]]},
#  {'detection_boxes': [[0.17648635804653168,
#     0.4917118549346924,
#     0.29754915833473206,
#     0.6080898642539978]],
#   'detection_classes': [['sit']],
#   'detection_scores': [[0.7299144268035889]]},
#  {'detection_boxes': [[0.17535392940044403,
#     0.49066153168678284,
#     0.29861584305763245,
#     0.6082299947738647]],
#   'detection_classes': [['sit']],
#   'detection_scores': [[0.6363920569419861]]},
#  {'detection_boxes': [[0.17579469084739685,
#     0.4944625496864319,
#     0.2989121079444885,
#     0.6090081930160522]],
#   'detection_classes': [['sit']],
#   'detection_scores': [[0.6734592318534851]]},
#  {'detection_boxes': [[0.17665347456932068,
#     0.49377936124801636,
#     0.3010026514530182,
#     0.611848771572113]],
#   'detection_classes': [['sit']],
#   'detection_scores': [[0.7469318509101868]]},
#  {'detection_boxes': [[0.17912089824676514,
#     0.4953131377696991,
#     0.29980698227882385,
#     0.6139258742332458]],
#   'detection_classes': [['sit']],
#   'detection_scores': [[0.7598220109939575]]},
#  {'detection_boxes': [[0.18077170848846436,
#     0.4939943253993988,
#     0.3015695810317993,
#     0.6124840974807739]],
#   'detection_classes': [['sit']],
#   'detection_scores': [[0.6894902586936951]]},
#  {'detection_boxes': [[0.18074333667755127,
#     0.4906107783317566,
#     0.2954481542110443,
#     0.6109312772750854]],
#   'detection_classes': [['sit']],
#   'detection_scores': [[0.547636091709137]]},
#  {'detection_boxes': [[0.18076545000076294,
#     0.49429214000701904,
#     0.29674288630485535,
#     0.6132606267929077],
#    [0.46000394225120544,
#     0.2898823618888855,
#     0.667154848575592,
#     0.5656967163085938]],
#   'detection_classes': [['sit'], ['carry/hold (an object)']],
#   'detection_scores': [[0.6356335282325745], [0.4473995864391327]]},
#  {'detection_boxes': [[0.1829085499048233,
#     0.49329689145088196,
#     0.29517143964767456,
#     0.6123881340026855],
#    [0.45987144112586975,
#     0.29459625482559204,
#     0.6764044165611267,
#     0.5770756602287292]],
#   'detection_classes': [['sit'], ['carry/hold (an object)']],
#   'detection_scores': [[0.6834774613380432], [0.47409841418266296]]},
#  {'detection_boxes': [[0.18173924088478088,
#     0.502718985080719,
#     0.2970365583896637,
#     0.6141365766525269],
#    [0.45687904953956604,
#     0.28405553102493286,
#     0.6791494488716125,
#     0.5801140069961548]],
#   'detection_classes': [['sit'], ['carry/hold (an object)']],
#   'detection_scores': [[0.6681467890739441], [0.45877572894096375]]},
#  {'detection_boxes': [[0.1819104552268982,
#     0.5063190460205078,
#     0.29582875967025757,
#     0.6166160106658936],
#    [0.459489643573761,
#     0.27713167667388916,
#     0.6645507216453552,
#     0.5733768343925476]],
#   'detection_classes': [['sit'], ['carry/hold (an object)']],
#   'detection_scores': [[0.6723701357841492], [0.4325910210609436]]},
#  {'detection_boxes': [[0.18240612745285034,
#     0.5101003050804138,
#     0.296624094247818,
#     0.621816873550415],
#    [0.45208513736724854,
#     0.26567715406417847,
#     0.6711186170578003,
#     0.5735323429107666]],
#   'detection_classes': [['sit'], ['carry/hold (an object)']],
#   'detection_scores': [[0.7023677229881287], [0.5495883226394653]]},
#  {'detection_boxes': [[0.18416622281074524,
#     0.5143324136734009,
#     0.29795363545417786,
#     0.6199615001678467],
#    [0.44897225499153137,
#     0.2550353407859802,
#     0.6783193349838257,
#     0.5775092244148254]],
#   'detection_classes': [['sit'], ['carry/hold (an object)']],
#   'detection_scores': [[0.6872088313102722], [0.6640701293945312]]},
#  {'detection_boxes': [[0.18600121140480042,
#     0.5084655284881592,
#     0.29431429505348206,
#     0.622732400894165],
#    [0.44811224937438965,
#     0.2568323016166687,
#     0.6821469664573669,
#     0.588127613067627]],
#   'detection_classes': [['sit'], ['carry/hold (an object)']],
#   'detection_scores': [[0.6675004363059998], [0.649488091468811]]},
#  {'detection_boxes': [[0.1866563856601715,
#     0.5127038359642029,
#     0.29420867562294006,
#     0.6228415966033936],
#    [0.45394715666770935,
#     0.2479260265827179,
#     0.6781659126281738,
#     0.5814415216445923]],
#   'detection_classes': [['sit'], ['carry/hold (an object)']],
#   'detection_scores': [[0.7872408032417297], [0.40651431679725647]]},
#  {'detection_boxes': [[0.182785764336586,
#     0.5088427066802979,
#     0.29452574253082275,
#     0.6307169198989868],
#    [0.4531470835208893,
#     0.24527038633823395,
#     0.6814062595367432,
#     0.5793102383613586]],
#   'detection_classes': [['sit'], ['carry/hold (an object)']],
#   'detection_scores': [[0.7081624865531921], [0.6309687495231628]]},
#  {'detection_boxes': [[0.44725510478019714,
#     0.23856203258037567,
#     0.6804099082946777,
#     0.5837621092796326],
#    [0.1839562952518463,
#     0.5187318325042725,
#     0.2963666617870331,
#     0.6251494288444519]],
#   'detection_classes': [['carry/hold (an object)'], ['sit']],
#   'detection_scores': [[0.7014398574829102], [0.6634817719459534]]},
#  {'detection_boxes': [[0.4445999562740326,
#     0.23597124218940735,
#     0.6895942091941833,
#     0.5851184725761414],
#    [0.18398748338222504,
#     0.5195541381835938,
#     0.29575246572494507,
#     0.6303719282150269]],
#   'detection_classes': [['carry/hold (an object)'], ['sit']],
#   'detection_scores': [[0.7194215059280396], [0.6217909455299377]]},
#  {'detection_boxes': [[0.4502764940261841,
#     0.23704485595226288,
#     0.6875513195991516,
#     0.5925524234771729]],
#   'detection_classes': [['carry/hold (an object)']],
#   'detection_scores': [[0.6164253950119019]]},
#  {'detection_boxes': [[0.44972604513168335,
#     0.24297577142715454,
#     0.6929940581321716,
#     0.5899359583854675],
#    [0.19076327979564667,
#     0.5243399739265442,
#     0.29779288172721863,
#     0.6380070447921753]],
#   'detection_classes': [['carry/hold (an object)', 'sit'], ['sit']],
#   'detection_scores': [[0.7174627184867859, 0.4106830954551697],
#    [0.624243438243866]]},
#  {'detection_boxes': [[0.45009300112724304,
#     0.23622985184192657,
#     0.6925919055938721,
#     0.5885478854179382],
#    [0.18662214279174805,
#     0.523493766784668,
#     0.3010059893131256,
#     0.6436148881912231]],
#   'detection_classes': [['carry/hold (an object)', 'sit'], ['sit']],
#   'detection_scores': [[0.7161332964897156, 0.4811308681964874],
#    [0.5513004064559937]]},
#  {'detection_boxes': [[0.45324569940567017,
#     0.2451249659061432,
#     0.686905562877655,
#     0.6009083986282349]],
#   'detection_classes': [['carry/hold (an object)', 'sit']],
#   'detection_scores': [[0.7606360912322998, 0.5672096014022827]]},
#  {'detection_boxes': [[0.4598093330860138,
#     0.24694418907165527,
#     0.6953986883163452,
#     0.6080591678619385]],
#   'detection_classes': [['carry/hold (an object)', 'sit']],
#   'detection_scores': [[0.5126322507858276, 0.4381156265735626]]},
#  {'detection_boxes': [[0.46843117475509644,
#     0.2433629184961319,
#     0.6881367564201355,
#     0.6178854703903198]],
#   'detection_classes': [['carry/hold (an object)']],
#   'detection_scores': [[0.5592777729034424]]},
#  {'detection_boxes': [[0.47623905539512634,
#     0.26959800720214844,
#     0.6903479099273682,
#     0.6313956379890442]],
#   'detection_classes': [['sit', 'carry/hold (an object)']],
#   'detection_scores': [[0.5208964943885803, 0.5007628202438354]]},
#  {'detection_boxes': [[0.47552043199539185,
#     0.28496766090393066,
#     0.7037278413772583,
#     0.6475459337234497]],
#   'detection_classes': [['sit', 'carry/hold (an object)']],
#   'detection_scores': [[0.6046721935272217, 0.5032462477684021]]},
#  {'detection_boxes': [[0.4823681712150574,
#     0.2971687614917755,
#     0.7020506858825684,
#     0.6508088111877441]],
#   'detection_classes': [['sit', 'carry/hold (an object)']],
#   'detection_scores': [[0.6278224587440491, 0.4685591161251068]]},
#  {'detection_boxes': [[0.19166617095470428,
#     0.5659714341163635,
#     0.3011155426502228,
#     0.6902182102203369],
#    [0.48456060886383057,
#     0.30432766675949097,
#     0.6951935291290283,
#     0.6790080070495605]],
#   'detection_classes': [['sit'], ['sit', 'carry/hold (an object)']],
#   'detection_scores': [[0.6388280391693115],
#    [0.5396771430969238, 0.4475896954536438]]},
#  {'detection_boxes': [[0.4873354434967041,
#     0.3047160506248474,
#     0.6938422918319702,
#     0.6697961688041687],
#    [0.19443126022815704,
#     0.5711958408355713,
#     0.29617786407470703,
#     0.6927424669265747]],
#   'detection_classes': [['sit', 'carry/hold (an object)'], ['sit']],
#   'detection_scores': [[0.6451976299285889, 0.4482353627681732],
#    [0.6178969144821167]]},
#  {'detection_boxes': [[0.48984554409980774,
#     0.31303778290748596,
#     0.7047167420387268,
#     0.6772769689559937],
#    [0.18653637170791626,
#     0.5758464932441711,
#     0.29709967970848083,
#     0.6955569386482239]],
#   'detection_classes': [['sit', 'carry/hold (an object)'], ['sit']],
#   'detection_scores': [[0.6455143094062805, 0.501240074634552],
#    [0.6080412864685059]]},
#  {'detection_boxes': [[0.49477916955947876,
#     0.30375945568084717,
#     0.7006590366363525,
#     0.6794898509979248]],
#   'detection_classes': [['sit']],
#   'detection_scores': [[0.6858825087547302]]},
#  {'detection_boxes': [[0.4925244450569153,
#     0.31011876463890076,
#     0.706052303314209,
#     0.6868476867675781],
#    [0.1891852766275406,
#     0.5794554948806763,
#     0.3014880120754242,
#     0.7026613354682922]],
#   'detection_classes': [['sit', 'carry/hold (an object)'], ['sit']],
#   'detection_scores': [[0.5890998244285583, 0.43126073479652405],
#    [0.5578740239143372]]},
#  {'detection_boxes': [[0.18927574157714844,
#     0.5805509686470032,
#     0.3017769753932953,
#     0.7029858231544495],
#    [0.488506555557251,
#     0.3185029625892639,
#     0.703229546546936,
#     0.6881967782974243]],
#   'detection_classes': [['sit'], ['sit', 'carry/hold (an object)']],
#   'detection_scores': [[0.5038625001907349],
#    [0.5022131204605103, 0.498148649930954]]},
#  {'detection_boxes': [[0.4894157648086548,
#     0.32459166646003723,
#     0.7111823558807373,
#     0.6869124174118042],
#    [0.18651831150054932,
#     0.5827009677886963,
#     0.302689790725708,
#     0.7057968378067017]],
#   'detection_classes': [['sit', 'carry/hold (an object)'], ['sit']],
#   'detection_scores': [[0.6108571290969849, 0.5572234392166138],
#    [0.5989717841148376]]},
#  {'detection_boxes': [[0.49782687425613403,
#     0.3252200186252594,
#     0.7122236490249634,
#     0.6829002499580383],
#    [0.18878173828125,
#     0.5936751365661621,
#     0.2871463894844055,
#     0.7092139720916748]],
#   'detection_classes': [['sit'], ['sit']],
#   'detection_scores': [[0.5452731847763062], [0.5304622054100037]]},
#  {'detection_boxes': [[0.19049561023712158,
#     0.5867453813552856,
#     0.29372599720954895,
#     0.7156860828399658],
#    [0.5028709173202515,
#     0.32848966121673584,
#     0.7110440731048584,
#     0.6926635503768921]],
#   'detection_classes': [['sit'], ['sit', 'carry/hold (an object)']],
#   'detection_scores': [[0.5768621563911438],
#    [0.4283227324485779, 0.41217732429504395]]},
#  {'detection_boxes': [[0.5010379552841187,
#     0.33133214712142944,
#     0.7061713933944702,
#     0.6898404359817505],
#    [0.19463539123535156,
#     0.589124858379364,
#     0.29905739426612854,
#     0.7196611762046814]],
#   'detection_classes': [['carry/hold (an object)', 'sit'], ['sit']],
#   'detection_scores': [[0.5421930551528931, 0.4574880003929138],
#    [0.5212801694869995]]},
#  {'detection_boxes': [[0.5002589225769043,
#     0.3398604393005371,
#     0.7097360491752625,
#     0.6995073556900024],
#    [0.19238770008087158,
#     0.5893576145172119,
#     0.29507073760032654,
#     0.7194845080375671]],
#   'detection_classes': [['carry/hold (an object)', 'sit'], ['sit']],
#   'detection_scores': [[0.5479027628898621, 0.4849592447280884],
#    [0.466004878282547]]},
#  {'detection_boxes': [[0.5084236860275269,
#     0.3554755747318268,
#     0.7126818895339966,
#     0.6988577842712402],
#    [0.1939084380865097,
#     0.5897794961929321,
#     0.30398550629615784,
#     0.7206565141677856]],
#   'detection_classes': [['sit', 'carry/hold (an object)'], ['sit']],
#   'detection_scores': [[0.6003729701042175, 0.5780306458473206],
#    [0.5592942237854004]]},
#  {'detection_boxes': [[0.1950618177652359,
#     0.5882877111434937,
#     0.30775463581085205,
#     0.7226496934890747],
#    [0.517128586769104,
#     0.37811705470085144,
#     0.7218599915504456,
#     0.7026773691177368]],
#   'detection_classes': [['sit'], ['sit']],
#   'detection_scores': [[0.7166688442230225], [0.6955118775367737]]},
#  {'detection_boxes': [[0.19723857939243317,
#     0.5899243354797363,
#     0.31384608149528503,
#     0.7237115502357483],
#    [0.516664981842041,
#     0.377035915851593,
#     0.7170630693435669,
#     0.6970706582069397]],
#   'detection_classes': [['sit'], ['sit', 'carry/hold (an object)']],
#   'detection_scores': [[0.7209832668304443],
#    [0.6920322179794312, 0.4469657838344574]]},
#  {'detection_boxes': [[0.5206261277198792,
#     0.380854070186615,
#     0.7205244302749634,
#     0.6979033946990967],
#    [0.1964101642370224,
#     0.5926624536514282,
#     0.32005882263183594,
#     0.7266567945480347]],
#   'detection_classes': [['sit', 'carry/hold (an object)'], ['sit']],
#   'detection_scores': [[0.8670770525932312, 0.5764127373695374],
#    [0.8088394403457642]]},
#  {'detection_boxes': [[0.5254391431808472,
#     0.39395982027053833,
#     0.7261459827423096,
#     0.699243426322937],
#    [0.19453205168247223,
#     0.5886815786361694,
#     0.320463091135025,
#     0.7248715758323669]],
#   'detection_classes': [['sit', 'carry/hold (an object)'], ['sit']],
#   'detection_scores': [[0.7946113348007202, 0.5794153213500977],
#    [0.6163800954818726]]},
#  {'detection_boxes': [[0.5291887521743774,
#     0.39811092615127563,
#     0.7312355041503906,
#     0.6979285478591919],
#    [0.1973867267370224,
#     0.5790655612945557,
#     0.32076573371887207,
#     0.7215765118598938]],
#   'detection_classes': [['sit', 'carry/hold (an object)'], ['sit']],
#   'detection_scores': [[0.6568370461463928, 0.43092045187950134],
#    [0.6000081896781921]]},
#  {'detection_boxes': [[0.5445047616958618,
#     0.39812690019607544,
#     0.7356554269790649,
#     0.6997530460357666],
#    [0.19672779738903046,
#     0.5740786790847778,
#     0.3202645778656006,
#     0.7236180305480957]],
#   'detection_classes': [['sit', 'carry/hold (an object)'], ['sit']],
#   'detection_scores': [[0.7511429786682129, 0.5922779440879822],
#    [0.7305087447166443]]},
#  {'detection_boxes': [[0.5540802478790283,
#     0.39321255683898926,
#     0.7360247373580933,
#     0.6921408772468567],
#    [0.19942963123321533,
#     0.584505021572113,
#     0.3213886320590973,
#     0.7259161472320557]],
#   'detection_classes': [['sit', 'carry/hold (an object)'], ['sit']],
#   'detection_scores': [[0.8175770044326782, 0.5805990099906921],
#    [0.8124052286148071]]},
#  {'detection_boxes': [[0.5562633872032166,
#     0.39654362201690674,
#     0.7382051944732666,
#     0.692824125289917],
#    [0.19561795890331268,
#     0.5849341154098511,
#     0.32709968090057373,
#     0.7236323356628418]],
#   'detection_classes': [['sit', 'carry/hold (an object)'], ['sit']],
#   'detection_scores': [[0.8130288124084473, 0.5844765901565552],
#    [0.7759098410606384]]},
#  {'detection_boxes': [[0.5576812028884888,
#     0.39930489659309387,
#     0.7439408302307129,
#     0.6915652751922607],
#    [0.20049543678760529,
#     0.5767213106155396,
#     0.32598838210105896,
#     0.7195355892181396]],
#   'detection_classes': [['sit', 'carry/hold (an object)'], ['sit']],
#   'detection_scores': [[0.7132351994514465, 0.40138447284698486],
#    [0.508717954158783]]},
#  {'detection_boxes': [[0.5634350776672363,
#     0.39802101254463196,
#     0.7492722272872925,
#     0.6851155757904053],
#    [0.20092396438121796,
#     0.5703619122505188,
#     0.32513153553009033,
#     0.7196214199066162]],
#   'detection_classes': [['sit', 'carry/hold (an object)'], ['sit']],
#   'detection_scores': [[0.8297401070594788, 0.4564233720302582],
#    [0.725267767906189]]},
#  {'detection_boxes': [[0.5744373798370361,
#     0.3970060348510742,
#     0.756058394908905,
#     0.6824530363082886],
#    [0.20466484129428864,
#     0.5735856294631958,
#     0.32809752225875854,
#     0.7208384871482849]],
#   'detection_classes': [['sit', 'carry/hold (an object)'], ['sit']],
#   'detection_scores': [[0.8020550012588501, 0.41881561279296875],
#    [0.7492223381996155]]},
#  {'detection_boxes': [[0.5742523074150085,
#     0.39807674288749695,
#     0.7540609836578369,
#     0.6829078793525696],
#    [0.20970015227794647,
#     0.5795546770095825,
#     0.324718177318573,
#     0.7156860828399658]],
#   'detection_classes': [['sit'], ['sit']],
#   'detection_scores': [[0.850490152835846], [0.5901666283607483]]},
#  {'detection_boxes': [[0.5830694437026978,
#     0.4006119668483734,
#     0.7540760636329651,
#     0.687187910079956]],
#   'detection_classes': [['sit']],
#   'detection_scores': [[0.7371233105659485]]},
#  {'detection_boxes': [[0.5837278366088867,
#     0.40732523798942566,
#     0.7572392225265503,
#     0.692928671836853],
#    [0.21624618768692017,
#     0.5649828910827637,
#     0.3348916172981262,
#     0.7126258611679077]],
#   'detection_classes': [['sit'], ['sit']],
#   'detection_scores': [[0.7368946671485901], [0.49224478006362915]]},
#  {'detection_boxes': [[0.5923458337783813,
#     0.40242645144462585,
#     0.7652803659439087,
#     0.6851397156715393],
#    [0.23480553925037384,
#     0.558762788772583,
#     0.34199386835098267,
#     0.7127777934074402]],
#   'detection_classes': [['sit'], ['sit']],
#   'detection_scores': [[0.7140466570854187], [0.6654466986656189]]},
#  {'detection_boxes': [[0.5981285572052002,
#     0.4052218198776245,
#     0.7673925161361694,
#     0.6965651512145996],
#    [0.2329545021057129,
#     0.571159303188324,
#     0.33383846282958984,
#     0.7107894420623779]],
#   'detection_classes': [['sit'], ['sit']],
#   'detection_scores': [[0.7560995221138], [0.6307311058044434]]},
#  {'detection_boxes': [[0.6070594787597656,
#     0.40989479422569275,
#     0.7731219530105591,
#     0.6898978352546692]],
#   'detection_classes': [['sit']],
#   'detection_scores': [[0.7588998079299927]]},
#  {'detection_boxes': [[0.6040205359458923,
#     0.41399550437927246,
#     0.7732560634613037,
#     0.6989665031433105]],
#   'detection_classes': [['sit']],
#   'detection_scores': [[0.8095490336418152]]},
#  {'detection_boxes': [[0.5969796776771545,
#     0.41660431027412415,
#     0.7771576046943665,
#     0.6722198724746704],
#    [0.26813748478889465,
#     0.5462037920951843,
#     0.36301955580711365,
#     0.6999343037605286]],
#   'detection_classes': [['sit'], ['sit']],
#   'detection_scores': [[0.8119130730628967], [0.4730175733566284]]},
#  {'detection_boxes': [[0.5952890515327454,
#     0.4111746549606323,
#     0.7779964208602905,
#     0.6998075842857361],
#    [0.2801683843135834,
#     0.5503624081611633,
#     0.3859102725982666,
#     0.6989721655845642]],
#   'detection_classes': [['sit'], ['sit']],
#   'detection_scores': [[0.8027763366699219], [0.4123590886592865]]},
#  {'detection_boxes': [[0.6042677164077759,
#     0.4202606976032257,
#     0.7957092523574829,
#     0.6714409589767456]],
#   'detection_classes': [['sit']],
#   'detection_scores': [[0.7269282937049866]]},
#  {'detection_boxes': [[0.6146003603935242,
#     0.4190528988838196,
#     0.7989433407783508,
#     0.6716907024383545]],
#   'detection_classes': [['sit']],
#   'detection_scores': [[0.7271759510040283]]},
#  {'detection_boxes': [[0.5883389115333557,
#     0.43150728940963745,
#     0.7838342785835266,
#     0.6746767163276672]],
#   'detection_classes': [['sit']],
#   'detection_scores': [[0.7593026161193848]]},
#  {'detection_boxes': [[0.5941722989082336,
#     0.4132491946220398,
#     0.789276659488678,
#     0.7364411950111389]],
#   'detection_classes': [['sit']],
#   'detection_scores': [[0.7929966449737549]]},
#  {'detection_boxes': [[0.6149134039878845,
#     0.40803462266921997,
#     0.8053913116455078,
#     0.7046825885772705]],
#   'detection_classes': [['sit']],
#   'detection_scores': [[0.757311999797821]]},
#  {'detection_boxes': [[0.6234078407287598,
#     0.4054437279701233,
#     0.8189787268638611,
#     0.7001351118087769],
#    [0.34626513719558716,
#     0.5396032929420471,
#     0.5136387944221497,
#     0.7016555666923523]],
#   'detection_classes': [['sit'], ['sit']],
#   'detection_scores': [[0.7704458236694336], [0.536162793636322]]},
#  {'detection_boxes': [[0.598647952079773,
#     0.39954835176467896,
#     0.8177734613418579,
#     0.7450852394104004]],
#   'detection_classes': [['sit']],
#   'detection_scores': [[0.7553289532661438]]},
#  {'detection_boxes': [[0.5912052989006042,
#     0.404844731092453,
#     0.8288848996162415,
#     0.7292457818984985],
#    [0.36439695954322815,
#     0.5340022444725037,
#     0.520373523235321,
#     0.7060747742652893]],
#   'detection_classes': [['sit'], ['sit']],
#   'detection_scores': [[0.7420692443847656], [0.6814678907394409]]},
#  {'detection_boxes': [[0.591750979423523,
#     0.39396554231643677,
#     0.8214865922927856,
#     0.7047852873802185],
#    [0.3888339698314667,
#     0.5339965224266052,
#     0.5225770473480225,
#     0.7024878859519958]],
#   'detection_classes': [['sit'], ['sit']],
#   'detection_scores': [[0.737033486366272], [0.5696632266044617]]},
#  {'detection_boxes': [[0.3943711519241333,
#     0.5382283926010132,
#     0.5308907628059387,
#     0.7020109295845032],
#    [0.6023210883140564,
#     0.39210596680641174,
#     0.8270122408866882,
#     0.7013304829597473]],
#   'detection_classes': [['sit'], ['sit']],
#   'detection_scores': [[0.8153603076934814], [0.5475950837135315]]},
#  {'detection_boxes': [[0.3985229432582855,
#     0.5312811136245728,
#     0.5302499532699585,
#     0.7080685496330261]],
#   'detection_classes': [['sit']],
#   'detection_scores': [[0.8669565320014954]]},
#  {'detection_boxes': [[0.40254318714141846,
#     0.5306106805801392,
#     0.533394992351532,
#     0.7057987451553345],
#    [0.9122473001480103,
#     0.47208335995674133,
#     0.9882348775863647,
#     0.6619516015052795]],
#   'detection_classes': [['sit'], ['sit']],
#   'detection_scores': [[0.8712308406829834], [0.7424771785736084]]},
#  {'detection_boxes': [[0.9194433093070984,
#     0.47695469856262207,
#     1.0,
#     0.6597692966461182],
#    [0.4039810299873352,
#     0.5289015769958496,
#     0.5274113416671753,
#     0.7032948136329651]],
#   'detection_classes': [['sit'], ['sit']],
#   'detection_scores': [[0.8151199221611023], [0.7468427419662476]]}]

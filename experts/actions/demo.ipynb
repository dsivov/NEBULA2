# %%
from stepwrapper import STEPDetector
import torch
# %load_ext autoreload
# %autoreload 2


# check GPU usage
print("Num GPUs Available: ", torch.cuda.device_count())

# create predictior with pretrained weights on AVA dataset (default arguments)
# weights currently (23.09.2021) in google drive:
#   https://drive.google.com/file/d/1hIzrTzR50pYwLLzu_5GpmEGY4Q-e1-BX/view
predictor = STEPDetector()
# Out:
# Num GPUs Available:  1
# loading model
# Loading pretrained model from /home/guy/NEBULA2/experts/actions/stepwrapper/STEP/pretrained/ava_step.pth
# Building I3D model...
# Building I3D head for global branch...
# Building I3D head for global branch...
# Building I3D head for global branch...
# Building I3D head for context branch...

# %%
import os

input_path = '/movies/scenecliptest00581.avi'
output_path = os.path.splitext(os.path.basename(input_path))[0] + '__OUT'

# %%
preds = predictor.predict_video(
    path_to_video=input_path,     # path to the foler containing the video frames
    # im_format='frame%04d.jpg',  # image format in folder. use default if movie file
    # source_fps=25,              # use the correct movie FPS for best performance
    # show_pbar=True,             # show/hide progress bar
    # num_workers=4               # num dataloader threads
)

# the returned value is a list of predictoins, one for each processed frame.
# a prediction is a dictionary in format:
# {
#   'detection_boxes': a list of lists of floating points. each list is a box for a single
#                      object in format xyxy, with values between 0 and 1.
#   'detection_scores': a list of lists floating points. each list contains the confidence
#                       for every predicted action class in the matching box region.
#   'detection_classes': a list of lists of string action names, e.g. ["stand", "carry"], ["sing", "dance"], ["sit"], ...
# }
preds
# Out:
# /home/guy/NEBULA2/experts/actions/Movies/scenecliptest00581
# Datalist len:  93
# 100%|██████████| 12/12 [01:09<00:00,  5.79s/it]
# [{'detection_boxes': [[0.6164363622665405,
#     0.0053323362953960896,
#     0.9871954917907715,
#     0.9849585890769958]],
#   'detection_classes': [['stand']],
#   'detection_scores': [[0.6204728484153748]]},
#  {'detection_boxes': [[0.6346981525421143,
#     0.005029869265854359,
#     0.981899082660675,
#     0.935187816619873]],
#   'detection_classes': [['stand']],
#   'detection_scores': [[0.591769278049469]]},
#  {'detection_boxes': [[0.6226340532302856,
#     0.0034991074353456497,
#     0.9843570590019226,
#     0.9556567668914795]],
#   'detection_classes': [['stand']],
#   'detection_scores': [[0.5590149164199829]]},
#  {'detection_boxes': [[0.6261329054832458,
#     0.0030264663510024548,
#     0.9775110483169556,
#     0.9265303015708923]],
#   'detection_classes': [['stand']],
#   'detection_scores': [[0.48647671937942505]]},
#  {'detection_boxes': [[0.6245140433311462,
#     0.0030533981043845415,
#     0.9697399735450745,
#     0.9109651446342468]],
#   'detection_classes': [['stand']],
#   'detection_scores': [[0.5760321617126465]]},
#  {'detection_boxes': [[0.5907623171806335,
#     0.0,
#     0.9725534319877625,
#     0.9597423076629639]],
#   'detection_classes': [['stand']],
#   'detection_scores': [[0.6430155038833618]]},
#  {'detection_boxes': [[0.6025829315185547,
#     0.0,
#     0.9755136966705322,
#     0.9762997627258301]],
#   'detection_classes': [['stand']],
#   'detection_scores': [[0.7696558237075806]]},
#  {'detection_boxes': [[0.5325703024864197,
#     0.0007641983102075756,
#     0.9977644085884094,
#     0.9751102924346924]],
#   'detection_classes': [['stand']],
#   'detection_scores': [[0.6928581595420837]]},
#  {'detection_boxes': [[0.4949725270271301,
#     0.0015682220691815019,
#     0.9929870367050171,
#     0.9486435055732727]],
#   'detection_classes': [['stand']],
#   'detection_scores': [[0.7178420424461365]]},
#  {'detection_boxes': [[0.41277945041656494,
#     0.0033182904589921236,
#     0.9898309707641602,
#     0.9977119565010071]],
#   'detection_classes': [['stand', 'sit', 'drink']],
#   'detection_scores': [[0.6555941104888916,
#     0.552731990814209,
#     0.44894665479660034]]},
#  {'detection_boxes': [[0.41766268014907837,
#     0.007416286505758762,
#     0.9901695251464844,
#     0.9955151081085205]],
#   'detection_classes': [['stand', 'sit']],
#   'detection_scores': [[0.652220606803894, 0.6008440256118774]]},
#  {'detection_boxes': [[0.41647371649742126,
#     0.007454528473317623,
#     0.9912664890289307,
#     0.9961040019989014]],
#   'detection_classes': [['sit', 'stand']],
#   'detection_scores': [[0.649273693561554, 0.5386541485786438]]},
#  {'detection_boxes': [[0.415746808052063,
#     0.0038297653663903475,
#     0.9890133738517761,
#     0.9993481636047363]],
#   'detection_classes': [['sit', 'stand']],
#   'detection_scores': [[0.6220707297325134, 0.548000693321228]]},
#  {'detection_boxes': [[0.3904528319835663,
#     0.0034228707663714886,
#     0.98955899477005,
#     0.9994609355926514]],
#   'detection_classes': [['sit', 'stand']],
#   'detection_scores': [[0.6293569207191467, 0.5630789995193481]]},
#  {'detection_boxes': [[0.4143739342689514,
#     0.004478874150663614,
#     0.9837101697921753,
#     0.9998997449874878]],
#   'detection_classes': [['stand', 'sit']],
#   'detection_scores': [[0.6107269525527954, 0.6056650876998901]]},
#  {'detection_boxes': [[0.41419100761413574,
#     0.005534381605684757,
#     0.9886472225189209,
#     1.0]],
#   'detection_classes': [['sit', 'stand']],
#   'detection_scores': [[0.6302037239074707, 0.48241788148880005]]},
#  {'detection_boxes': [[0.40851688385009766,
#     0.0053127482533454895,
#     0.9889219999313354,
#     1.0]],
#   'detection_classes': [['sit', 'stand']],
#   'detection_scores': [[0.6759327054023743, 0.48424240946769714]]},
#  {'detection_boxes': [[0.40187695622444153,
#     0.007892824709415436,
#     0.9842527508735657,
#     1.0]],
#   'detection_classes': [['sit', 'stand', 'carry/hold (an object)']],
#   'detection_scores': [[0.7292364239692688,
#     0.44398075342178345,
#     0.42549118399620056]]},
#  {'detection_boxes': [[0.41141510009765625,
#     0.010394096374511719,
#     0.9890978932380676,
#     1.0]],
#   'detection_classes': [['sit']],
#   'detection_scores': [[0.792029082775116]]},
#  {'detection_boxes': [[0.39894798398017883,
#     0.013693542219698429,
#     0.991802453994751,
#     1.0]],
#   'detection_classes': [['sit']],
#   'detection_scores': [[0.7714129090309143]]},
#  {'detection_boxes': [[0.4245918393135071,
#     0.00480434438213706,
#     0.9870305061340332,
#     1.0]],
#   'detection_classes': [['sit']],
#   'detection_scores': [[0.7804728746414185]]},
#  {'detection_boxes': [[0.40528690814971924,
#     0.005658111535012722,
#     0.991915762424469,
#     1.0]],
#   'detection_classes': [['sit']],
#   'detection_scores': [[0.7768683433532715]]},
#  {'detection_boxes': [[0.4059489369392395,
#     0.007647933904081583,
#     0.9891420006752014,
#     1.0]],
#   'detection_classes': [['sit', 'stand']],
#   'detection_scores': [[0.8221068382263184, 0.4132280945777893]]},
#  {'detection_boxes': [[0.40626612305641174,
#     0.012706146575510502,
#     0.9932953119277954,
#     1.0]],
#   'detection_classes': [['sit']],
#   'detection_scores': [[0.8253152966499329]]},
#  {'detection_boxes': [[0.4322316348552704,
#     0.0054536247625947,
#     0.9895886182785034,
#     0.999753475189209]],
#   'detection_classes': [['sit', 'stand']],
#   'detection_scores': [[0.7089738249778748, 0.44049152731895447]]},
#  {'detection_boxes': [[0.41837185621261597,
#     0.010273551568388939,
#     0.9896000623703003,
#     1.0]],
#   'detection_classes': [['sit']],
#   'detection_scores': [[0.8167624473571777]]},
#  {'detection_boxes': [[0.4138844311237335,
#     0.012473106384277344,
#     0.9894500970840454,
#     1.0]],
#   'detection_classes': [['sit']],
#   'detection_scores': [[0.7824758291244507]]},
#  {'detection_boxes': [[0.4074137806892395,
#     0.0164906308054924,
#     0.9941270351409912,
#     1.0]],
#   'detection_classes': [['sit']],
#   'detection_scores': [[0.7765418887138367]]},
#  {'detection_boxes': [[0.4157063961029053,
#     0.014450855553150177,
#     0.99014812707901,
#     0.9973494410514832]],
#   'detection_classes': [['sit', 'stand']],
#   'detection_scores': [[0.6327009201049805, 0.46488747000694275]]},
#  {'detection_boxes': [[0.38502028584480286,
#     0.016605034470558167,
#     0.9839779734611511,
#     0.9961997866630554]],
#   'detection_classes': [['sit']],
#   'detection_scores': [[0.7274498343467712]]},
#  {'detection_boxes': [[0.4350947141647339,
#     0.010145187377929688,
#     0.9905000329017639,
#     0.9990883469581604]],
#   'detection_classes': [['sit', 'stand']],
#   'detection_scores': [[0.6448390483856201, 0.4268825352191925]]},
#  {'detection_boxes': [[0.4717104434967041,
#     0.013826027512550354,
#     0.9875404834747314,
#     1.0]],
#   'detection_classes': [['sit', 'stand']],
#   'detection_scores': [[0.656665563583374, 0.43211010098457336]]},
#  {'detection_boxes': [[0.46787258982658386,
#     0.013861026614904404,
#     0.9893336892127991,
#     0.9992381930351257]],
#   'detection_classes': [['sit', 'stand']],
#   'detection_scores': [[0.6356247663497925, 0.4419656991958618]]},
#  {'detection_boxes': [[0.4883826971054077,
#     0.00984945334494114,
#     0.991301953792572,
#     1.0],
#    [0.29871174693107605, 0.17977328598499298, 0.651149570941925, 1.0]],
#   'detection_classes': [['sit', 'stand'], ['sit']],
#   'detection_scores': [[0.6534231901168823, 0.40426376461982727],
#    [0.4015567898750305]]},
#  {'detection_boxes': [[0.4541175961494446,
#     0.009605025872588158,
#     0.986497163772583,
#     1.0],
#    [0.32191115617752075, 0.185186505317688, 0.6540544033050537, 1.0]],
#   'detection_classes': [['sit'], ['sit']],
#   'detection_scores': [[0.7254708409309387], [0.46417564153671265]]},
#  {'detection_boxes': [[0.46364501118659973,
#     0.02927173674106598,
#     0.9814425706863403,
#     1.0],
#    [0.3386962115764618,
#     0.17540951073169708,
#     0.64913010597229,
#     0.9990929961204529]],
#   'detection_classes': [['sit'], ['sit']],
#   'detection_scores': [[0.6640647649765015], [0.5119157433509827]]},
#  {'detection_boxes': [[0.48645997047424316,
#     0.00635883305221796,
#     0.9933391809463501,
#     1.0],
#    [0.3322913348674774, 0.17004451155662537, 0.6512414813041687, 1.0]],
#   'detection_classes': [['sit', 'talk to (e.g., self, a person, a group)'],
#    ['sit']],
#   'detection_scores': [[0.7415229082107544, 0.41663146018981934],
#    [0.5233917832374573]]},
#  {'detection_boxes': [[0.5060180425643921,
#     0.015101280063390732,
#     0.9940249919891357,
#     1.0],
#    [0.3546036183834076, 0.17161472141742706, 0.6527773141860962, 1.0]],
#   'detection_classes': [['sit'], ['sit']],
#   'detection_scores': [[0.726728081703186], [0.5048145651817322]]},
#  {'detection_boxes': [[0.4751252830028534,
#     0.006643753033131361,
#     0.9888603091239929,
#     1.0],
#    [0.3515608310699463, 0.17316482961177826, 0.6552513837814331, 1.0]],
#   'detection_classes': [['sit'], ['sit']],
#   'detection_scores': [[0.6481095552444458], [0.4735340178012848]]},
#  {'detection_boxes': [[0.5004763603210449,
#     0.010832023806869984,
#     0.995710015296936,
#     1.0],
#    [0.3600800335407257, 0.17272499203681946, 0.649513304233551, 1.0]],
#   'detection_classes': [['sit'], ['sit']],
#   'detection_scores': [[0.6073528528213501], [0.5148981213569641]]},
#  {'detection_boxes': [[0.49613863229751587,
#     0.012197781354188919,
#     0.9942284822463989,
#     1.0],
#    [0.3626861572265625, 0.17198505997657776, 0.650353193283081, 1.0]],
#   'detection_classes': [['sit', 'talk to (e.g., self, a person, a group)'],
#    ['sit']],
#   'detection_scores': [[0.629780650138855, 0.45138201117515564],
#    [0.4883818030357361]]},
#  {'detection_boxes': [[0.5051275491714478,
#     0.0034465789794921875,
#     0.9933755397796631,
#     1.0],
#    [0.3523827791213989, 0.1731787472963333, 0.6567041873931885, 1.0]],
#   'detection_classes': [['sit', 'stand'], ['sit']],
#   'detection_scores': [[0.5864508152008057, 0.44917359948158264],
#    [0.4333547353744507]]},
#  {'detection_boxes': [[0.511736273765564,
#     0.00941261276602745,
#     0.9950486421585083,
#     1.0],
#    [0.3508092164993286, 0.1768297255039215, 0.6561224460601807, 1.0]],
#   'detection_classes': [['sit', 'stand'], ['sit']],
#   'detection_scores': [[0.6174259185791016, 0.4035159647464752],
#    [0.46649250388145447]]},
#  {'detection_boxes': [[0.5153760313987732,
#     0.0077050779946148396,
#     0.9942838549613953,
#     1.0],
#    [0.3541346788406372, 0.1797437220811844, 0.6543222069740295, 1.0]],
#   'detection_classes': [['sit', 'stand'], ['sit']],
#   'detection_scores': [[0.6107669472694397, 0.4109310805797577],
#    [0.5276694297790527]]},
#  {'detection_boxes': [[0.5057606101036072,
#     0.007725676987320185,
#     0.9931038022041321,
#     1.0],
#    [0.35752540826797485, 0.1849796622991562, 0.6551997661590576, 1.0]],
#   'detection_classes': [['sit',
#     'stand',
#     'talk to (e.g., self, a person, a group)'],
#    ['sit']],
#   'detection_scores': [[0.510421097278595,
#     0.4722919166088104,
#     0.40266335010528564],
#    [0.4263973832130432]]},
#  {'detection_boxes': [[0.5200018882751465,
#     0.006380818784236908,
#     0.9930932521820068,
#     1.0],
#    [0.3491367995738983, 0.18217480182647705, 0.6576574444770813, 1.0]],
#   'detection_classes': [['sit',
#     'watch (a person)',
#     'talk to (e.g., self, a person, a group)'],
#    ['sit']],
#   'detection_scores': [[0.6360778212547302,
#     0.44634509086608887,
#     0.41167905926704407],
#    [0.5239788889884949]]},
#  {'detection_boxes': [[0.5175634026527405,
#     0.007118059787899256,
#     0.9949020743370056,
#     1.0],
#    [0.3427307903766632, 0.17961475253105164, 0.676344096660614, 1.0]],
#   'detection_classes': [['sit',
#     'talk to (e.g., self, a person, a group)',
#     'stand'],
#    ['sit']],
#   'detection_scores': [[0.6176505088806152,
#     0.5162646770477295,
#     0.43241167068481445],
#    [0.5721350908279419]]},
#  {'detection_boxes': [[0.5277488231658936,
#     0.005163815803825855,
#     0.9944354891777039,
#     1.0],
#    [0.3391932547092438,
#     0.18462055921554565,
#     0.6708051562309265,
#     0.9981889128684998]],
#   'detection_classes': [['sit', 'stand', 'watch (a person)'], ['sit']],
#   'detection_scores': [[0.5655177235603333,
#     0.5031970739364624,
#     0.4038381278514862],
#    [0.5407018661499023]]},
#  {'detection_boxes': [[0.5203007459640503,
#     0.007098846137523651,
#     0.9950591325759888,
#     1.0],
#    [0.34391242265701294, 0.1888495683670044, 0.6698350310325623, 1.0]],
#   'detection_classes': [['sit', 'stand'], ['sit']],
#   'detection_scores': [[0.6250899434089661, 0.41717174649238586],
#    [0.5985979437828064]]},
#  {'detection_boxes': [[0.5342025756835938,
#     0.0034284591674804688,
#     0.9951803088188171,
#     1.0],
#    [0.3296068608760834, 0.18878547847270966, 0.6784437298774719, 1.0]],
#   'detection_classes': [['sit', 'stand', 'watch (a person)'], ['sit']],
#   'detection_scores': [[0.6368471384048462,
#     0.4275418221950531,
#     0.4177721440792084],
#    [0.5980436205863953]]},
#  {'detection_boxes': [[0.5330857038497925,
#     0.0044506266713142395,
#     0.9949885606765747,
#     1.0],
#    [0.336556077003479, 0.18316853046417236, 0.6811096668243408, 1.0]],
#   'detection_classes': [['sit', 'stand'], ['sit']],
#   'detection_scores': [[0.5999956727027893, 0.454019695520401],
#    [0.5475319027900696]]},
#  {'detection_boxes': [[0.5324257016181946,
#     0.0032408712431788445,
#     0.9954565763473511,
#     1.0],
#    [0.34193000197410583,
#     0.17982624471187592,
#     0.6665960550308228,
#     0.9954022169113159]],
#   'detection_classes': [['sit', 'stand'], ['sit']],
#   'detection_scores': [[0.5385407209396362, 0.439552366733551],
#    [0.48803356289863586]]},
#  {'detection_boxes': [[0.34167611598968506,
#     0.18020568788051605,
#     0.6674700379371643,
#     0.9984951019287109],
#    [0.5321722030639648, 0.004673786461353302, 0.9947441220283508, 1.0]],
#   'detection_classes': [['sit'], ['sit', 'stand']],
#   'detection_scores': [[0.5938163995742798],
#    [0.5870987176895142, 0.4251767098903656]]},
#  {'detection_boxes': [[0.5396691560745239,
#     0.002042789477854967,
#     0.9929097890853882,
#     1.0],
#    [0.33967098593711853,
#     0.18136726319789886,
#     0.6696417331695557,
#     0.998872697353363]],
#   'detection_classes': [['sit', 'talk to (e.g., self, a person, a group)'],
#    ['sit']],
#   'detection_scores': [[0.6816936135292053, 0.46049100160598755],
#    [0.6427887678146362]]},
#  {'detection_boxes': [[0.5497465133666992,
#     0.0064960867166519165,
#     0.9947789311408997,
#     1.0],
#    [0.33927151560783386,
#     0.1849624663591385,
#     0.6666691303253174,
#     0.9976369738578796]],
#   'detection_classes': [['sit',
#     'stand',
#     'talk to (e.g., self, a person, a group)'],
#    ['sit']],
#   'detection_scores': [[0.5890023708343506,
#     0.4351319968700409,
#     0.432489812374115],
#    [0.5748400688171387]]},
#  {'detection_boxes': [[0.556037962436676,
#     0.005353889428079128,
#     0.9958035945892334,
#     1.0],
#    [0.3362218141555786,
#     0.1862574815750122,
#     0.6937724351882935,
#     0.993125855922699]],
#   'detection_classes': [['sit', 'talk to (e.g., self, a person, a group)'],
#    ['sit']],
#   'detection_scores': [[0.6744419932365417, 0.43474429845809937],
#    [0.6732355356216431]]},
#  {'detection_boxes': [[0.5450668931007385,
#     0.004356346093118191,
#     0.9929160475730896,
#     1.0],
#    [0.3315460979938507,
#     0.1890469789505005,
#     0.6873496770858765,
#     0.9986879229545593]],
#   'detection_classes': [['talk to (e.g., self, a person, a group)',
#     'sit',
#     'watch (a person)'],
#    ['sit', 'listen to (a person)']],
#   'detection_scores': [[0.6801199913024902,
#     0.6230198740959167,
#     0.40216583013534546],
#    [0.6405265927314758, 0.5659569501876831]]},
#  {'detection_boxes': [[0.5555822849273682,
#     0.006828422658145428,
#     0.9939877986907959,
#     1.0],
#    [0.3374444842338562,
#     0.18292689323425293,
#     0.6792055368423462,
#     0.9991306066513062]],
#   'detection_classes': [['talk to (e.g., self, a person, a group)', 'sit'],
#    ['sit', 'listen to (a person)']],
#   'detection_scores': [[0.7568517923355103, 0.6508335471153259],
#    [0.6597229838371277, 0.5791402459144592]]},
#  {'detection_boxes': [[0.5476421117782593,
#     0.0066581531427800655,
#     0.995120108127594,
#     1.0],
#    [0.3379577696323395,
#     0.18392139673233032,
#     0.6838660836219788,
#     0.9960759878158569]],
#   'detection_classes': [['talk to (e.g., self, a person, a group)',
#     'sit',
#     'stand',
#     'watch (a person)'],
#    ['sit', 'listen to (a person)']],
#   'detection_scores': [[0.6381992101669312,
#     0.6167712211608887,
#     0.41388899087905884,
#     0.4004218280315399],
#    [0.5991721749305725, 0.47685766220092773]]},
#  {'detection_boxes': [[0.5455543994903564,
#     0.0035317230504006147,
#     0.9952652454376221,
#     1.0],
#    [0.343840628862381,
#     0.18613602221012115,
#     0.6714654564857483,
#     0.9951424598693848]],
#   'detection_classes': [['talk to (e.g., self, a person, a group)',
#     'sit',
#     'stand',
#     'watch (a person)'],
#    ['sit']],
#   'detection_scores': [[0.6160271763801575,
#     0.568913459777832,
#     0.5079229474067688,
#     0.4125277101993561],
#    [0.5800730586051941]]},
#  {'detection_boxes': [[0.5470789670944214,
#     0.0031206130515784025,
#     0.993356466293335,
#     0.9999475479125977],
#    [0.3438606262207031,
#     0.18114840984344482,
#     0.6808556318283081,
#     0.9973771572113037]],
#   'detection_classes': [['stand',
#     'talk to (e.g., self, a person, a group)',
#     'sit'],
#    ['sit']],
#   'detection_scores': [[0.5798889398574829,
#     0.4979133903980255,
#     0.46423184871673584],
#    [0.5085241198539734]]},
#  {'detection_boxes': [[0.5445749759674072,
#     0.0038684718310832977,
#     0.991457462310791,
#     0.9998237490653992],
#    [0.34566551446914673,
#     0.18118087947368622,
#     0.6806203722953796,
#     0.9965571761131287]],
#   'detection_classes': [['talk to (e.g., self, a person, a group)',
#     'stand',
#     'sit'],
#    ['sit']],
#   'detection_scores': [[0.5951208472251892,
#     0.5580002069473267,
#     0.4865001440048218],
#    [0.4825437366962433]]},
#  {'detection_boxes': [[0.5498665571212769,
#     0.002359720878303051,
#     0.9915194511413574,
#     0.9996347427368164],
#    [0.3378768265247345,
#     0.17772361636161804,
#     0.6948727369308472,
#     0.9981785416603088]],
#   'detection_classes': [['sit',
#     'talk to (e.g., self, a person, a group)',
#     'stand'],
#    ['sit']],
#   'detection_scores': [[0.5781322717666626,
#     0.5622940063476562,
#     0.4583759009838104],
#    [0.5701833963394165]]},
#  {'detection_boxes': [[0.5483875870704651,
#     0.0020451610907912254,
#     0.9892933964729309,
#     0.9992677569389343],
#    [0.34354451298713684,
#     0.1803453117609024,
#     0.6907920837402344,
#     0.9996584057807922]],
#   'detection_classes': [['talk to (e.g., self, a person, a group)',
#     'stand',
#     'sit'],
#    ['sit']],
#   'detection_scores': [[0.648337185382843,
#     0.5969682335853577,
#     0.41903358697891235],
#    [0.4415873885154724]]},
#  {'detection_boxes': [[0.5543131232261658,
#     0.0014667002251371741,
#     0.9916167259216309,
#     0.998566210269928],
#    [0.34202995896339417, 0.1803467571735382, 0.6981577277183533, 1.0]],
#   'detection_classes': [['talk to (e.g., self, a person, a group)',
#     'stand',
#     'watch (a person)'],
#    ['sit', 'listen to (a person)']],
#   'detection_scores': [[0.7748773097991943,
#     0.6478063464164734,
#     0.43049830198287964],
#    [0.421153724193573, 0.4049992561340332]]},
#  {'detection_boxes': [[0.5499092936515808,
#     0.00239365897141397,
#     0.9906620383262634,
#     0.9997456073760986],
#    [0.3465351164340973, 0.18643493950366974, 0.696076512336731, 1.0]],
#   'detection_classes': [['talk to (e.g., self, a person, a group)',
#     'stand',
#     'sit'],
#    ['listen to (a person)']],
#   'detection_scores': [[0.7138097882270813,
#     0.5955503582954407,
#     0.41271650791168213],
#    [0.43158525228500366]]},
#  {'detection_boxes': [[0.33868759870529175,
#     0.1897965967655182,
#     0.6995778679847717,
#     0.9994924068450928],
#    [0.5462946891784668,
#     0.0020277404692023993,
#     0.9930878281593323,
#     0.9994057416915894]],
#   'detection_classes': [['sit'],
#    ['sit', 'talk to (e.g., self, a person, a group)']],
#   'detection_scores': [[0.6583446860313416],
#    [0.6215565204620361, 0.6141212582588196]]},
#  {'detection_boxes': [[0.5458460450172424,
#     0.0020324198994785547,
#     0.9933245182037354,
#     0.9970343708992004],
#    [0.34071800112724304, 0.18647460639476776, 0.6941143870353699, 1.0]],
#   'detection_classes': [['talk to (e.g., self, a person, a group)',
#     'sit',
#     'stand'],
#    ['sit']],
#   'detection_scores': [[0.5937581658363342,
#     0.5307000279426575,
#     0.4750913381576538],
#    [0.5509718656539917]]},
#  {'detection_boxes': [[0.5577535033226013,
#     0.004032300319522619,
#     0.9957995414733887,
#     0.9954554438591003],
#    [0.33709055185317993,
#     0.18589748442173004,
#     0.6900771260261536,
#     0.9996404647827148]],
#   'detection_classes': [['talk to (e.g., self, a person, a group)',
#     'stand',
#     'watch (a person)'],
#    ['listen to (a person)', 'sit']],
#   'detection_scores': [[0.7148820757865906,
#     0.6008527278900146,
#     0.48927614092826843],
#    [0.5163212418556213, 0.4523293972015381]]},
#  {'detection_boxes': [[0.5490186810493469,
#     0.006325326859951019,
#     0.9938384890556335,
#     0.9959421753883362],
#    [0.3395763635635376, 0.18663251399993896, 0.6924661993980408, 1.0]],
#   'detection_classes': [['talk to (e.g., self, a person, a group)',
#     'stand',
#     'watch (a person)'],
#    ['listen to (a person)', 'sit']],
#   'detection_scores': [[0.7459500432014465,
#     0.57451993227005,
#     0.47279536724090576],
#    [0.530917227268219, 0.43946346640586853]]},
#  {'detection_boxes': [[0.5542799830436707,
#     0.0016939067281782627,
#     0.9920126795768738,
#     0.9925203323364258],
#    [0.33912044763565063,
#     0.1907988339662552,
#     0.6809033155441284,
#     0.994460940361023]],
#   'detection_classes': [['talk to (e.g., self, a person, a group)',
#     'watch (a person)',
#     'sit',
#     'stand'],
#    ['listen to (a person)', 'sit']],
#   'detection_scores': [[0.7825570702552795,
#     0.5172392725944519,
#     0.4718933403491974,
#     0.4134925603866577],
#    [0.6073497533798218, 0.5220555663108826]]},
#  {'detection_boxes': [[0.547272801399231,
#     0.0021315894555300474,
#     0.9935687184333801,
#     0.9932899475097656],
#    [0.3380558490753174,
#     0.1873118281364441,
#     0.6825770139694214,
#     0.9956192970275879]],
#   'detection_classes': [['talk to (e.g., self, a person, a group)',
#     'sit',
#     'watch (a person)'],
#    ['sit', 'listen to (a person)']],
#   'detection_scores': [[0.7807908654212952,
#     0.5239390134811401,
#     0.44368690252304077],
#    [0.5936828851699829, 0.5559401512145996]]},
#  {'detection_boxes': [[0.5448514819145203,
#     0.004408922046422958,
#     0.9936769604682922,
#     0.9926877617835999],
#    [0.3331134021282196,
#     0.18284156918525696,
#     0.6783616542816162,
#     0.9961384534835815]],
#   'detection_classes': [['talk to (e.g., self, a person, a group)',
#     'watch (a person)',
#     'stand',
#     'sit'],
#    ['sit', 'listen to (a person)']],
#   'detection_scores': [[0.7990756034851074,
#     0.5133642554283142,
#     0.423198401927948,
#     0.41320472955703735],
#    [0.4939523935317993, 0.46172913908958435]]},
#  {'detection_boxes': [[0.5366142988204956,
#     0.005819765850901604,
#     0.9926483631134033,
#     0.9967843890190125],
#    [0.3328614830970764,
#     0.1813770830631256,
#     0.6840064525604248,
#     0.9976586103439331]],
#   'detection_classes': [['talk to (e.g., self, a person, a group)',
#     'watch (a person)',
#     'sit'],
#    ['sit', 'listen to (a person)']],
#   'detection_scores': [[0.8114190101623535,
#     0.45990991592407227,
#     0.4344141185283661],
#    [0.5190957188606262, 0.45893558859825134]]},
#  {'detection_boxes': [[0.5301275849342346,
#     0.004053713288158178,
#     0.9946185946464539,
#     0.9919120669364929],
#    [0.3352656662464142,
#     0.18570736050605774,
#     0.646548867225647,
#     0.9954759478569031]],
#   'detection_classes': [['talk to (e.g., self, a person, a group)',
#     'sit',
#     'watch (a person)'],
#    ['sit']],
#   'detection_scores': [[0.8088459968566895,
#     0.5224396586418152,
#     0.4484282433986664],
#    [0.5461404323577881]]},
#  {'detection_boxes': [[0.5260846614837646,
#     0.006881306413561106,
#     0.9931890368461609,
#     0.9913987517356873],
#    [0.3294225037097931,
#     0.1836976408958435,
#     0.6719650626182556,
#     0.9962086081504822]],
#   'detection_classes': [['talk to (e.g., self, a person, a group)',
#     'sit',
#     'watch (a person)'],
#    ['sit', 'listen to (a person)']],
#   'detection_scores': [[0.8003412485122681,
#     0.5031094551086426,
#     0.46978759765625],
#    [0.5694828033447266, 0.47655558586120605]]},
#  {'detection_boxes': [[0.42522183060646057,
#     0.002288551302626729,
#     0.9883447289466858,
#     0.9897265434265137]],
#   'detection_classes': [['stand']],
#   'detection_scores': [[0.793520450592041]]},
#  {'detection_boxes': [[0.44584450125694275,
#     0.0016638183733448386,
#     0.9910701513290405,
#     0.9886681437492371]],
#   'detection_classes': [['stand']],
#   'detection_scores': [[0.8058184385299683]]},
#  {'detection_boxes': [[0.4546738862991333,
#     0.0,
#     0.9899630546569824,
#     0.9967588782310486]],
#   'detection_classes': [['stand']],
#   'detection_scores': [[0.6564337015151978]]},
#  {'detection_boxes': [[0.434885174036026,
#     0.008578605949878693,
#     0.9902580976486206,
#     0.9932887554168701]],
#   'detection_classes': [['stand']],
#   'detection_scores': [[0.7485828399658203]]},
#  {'detection_boxes': [[0.458779513835907,
#     0.012282256968319416,
#     0.9888980984687805,
#     1.0]],
#   'detection_classes': [['stand']],
#   'detection_scores': [[0.6438856720924377]]},
#  {'detection_boxes': [[0.5006533861160278,
#     0.007279129233211279,
#     0.993761420249939,
#     0.9967014193534851]],
#   'detection_classes': [['stand']],
#   'detection_scores': [[0.6193760633468628]]},
#  {'detection_boxes': [[0.4996357858181,
#     0.002355117816478014,
#     0.9920871257781982,
#     0.9990580081939697]],
#   'detection_classes': [['stand']],
#   'detection_scores': [[0.7250279784202576]]},
#  {'detection_boxes': [[0.45843756198883057,
#     0.006916046142578125,
#     0.9938382506370544,
#     0.9990324378013611]],
#   'detection_classes': [['stand']],
#   'detection_scores': [[0.6310908794403076]]},
#  {'detection_boxes': [[0.4785131812095642,
#     0.010646248236298561,
#     0.9908871650695801,
#     0.9998779296875]],
#   'detection_classes': [['stand']],
#   'detection_scores': [[0.641234815120697]]},
#  {'detection_boxes': [[0.46821364760398865,
#     0.009297179989516735,
#     0.9937098622322083,
#     0.9987779259681702]],
#   'detection_classes': [['stand']],
#   'detection_scores': [[0.7231099605560303]]},
#  {'detection_boxes': [[0.45940858125686646,
#     0.007225417997688055,
#     0.995220959186554,
#     1.0]],
#   'detection_classes': [['stand']],
#   'detection_scores': [[0.7156823873519897]]},
#  {'detection_boxes': [[0.45708489418029785,
#     0.008438186720013618,
#     0.9973116517066956,
#     0.9996113777160645]],
#   'detection_classes': [['stand']],
#   'detection_scores': [[0.7464452981948853]]},
#  {'detection_boxes': [[0.4708007574081421,
#     0.010982169769704342,
#     0.9984910488128662,
#     0.9935969710350037]],
#   'detection_classes': [['stand']],
#   'detection_scores': [[0.639356791973114]]},
#  {'detection_boxes': [[0.46673664450645447,
#     0.008280639536678791,
#     0.9982519745826721,
#     0.9974033832550049]],
#   'detection_classes': [['stand']],
#   'detection_scores': [[0.642861545085907]]},
#  {'detection_boxes': [[0.47876203060150146,
#     0.004375724587589502,
#     1.0,
#     0.9974008202552795]],
#   'detection_classes': [['stand']],
#   'detection_scores': [[0.5518841743469238]]},
#  {'detection_boxes': [[0.4894927442073822,
#     0.006359004881232977,
#     1.0,
#     0.990568995475769]],
#   'detection_classes': [['stand', 'listen to (a person)']],
#   'detection_scores': [[0.6426539421081543, 0.41116660833358765]]},
#  {'detection_boxes': [[0.5060545802116394, 0.005876426585018635, 1.0, 1.0]],
#   'detection_classes': [['stand']],
#   'detection_scores': [[0.5695329308509827]]}]

# %%
from ActionAnnotator import ActionAnnotator

# save annotated video
ActionAnnotator().annotate_video(input_path, {str(i): p for i, p in enumerate(preds)}, output_path)
# Out:
# annotating /movies/scenecliptest00581.avi: 100%|██████████| 94/94 [00:02<00:00, 41.66it/s]
